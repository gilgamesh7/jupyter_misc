# %% [markdown]
# # Life Expectancy Exercise
# [datasource - Worldbank](https://data.worldbank.org/indicator/SP.DYN.LE00.IN)

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("data\life_expectancy\API_SP.DYN.LE00.IN_DS2_en_csv_v2_1865151.csv",header=2,index_col=[0,1,2,3])
df.head()
# Out:
#                                                                                     1960  \
# Country Name Country Code Indicator Name                          Indicator Code
# Aruba        ABW          Life expectancy at birth, total (years) SP.DYN.LE00.IN  65.662
# Afghanistan  AFG          Life expectancy at birth, total (years) SP.DYN.LE00.IN  32.446
# Angola       AGO          Life expectancy at birth, total (years) SP.DYN.LE00.IN  37.524
# Albania      ALB          Life expectancy at birth, total (years) SP.DYN.LE00.IN  62.283
# Andorra      AND          Life expectancy at birth, total (years) SP.DYN.LE00.IN     NaN
#
#                                                                                     1961  \
# Country Name Country Code Indicator Name                          Indicator Code
# Aruba        ABW          Life expectancy at birth, total (years) SP.DYN.LE00.IN  66.074
# Afghanistan  AFG          Life expectancy at birth, total (years) SP.DYN.LE00.IN  32.962
# ...

# %%
df['1960']
# Out:
# Country Name  Country Code  Indicator Name                           Indicator Code
# Aruba         ABW           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    65.662
# Afghanistan   AFG           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    32.446
# Angola        AGO           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    37.524
# Albania       ALB           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    62.283
# Andorra       AND           Life expectancy at birth, total (years)  SP.DYN.LE00.IN       NaN
#                                                                                         ...
# Kosovo        XKX           Life expectancy at birth, total (years)  SP.DYN.LE00.IN       NaN
# Yemen, Rep.   YEM           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    29.919
# South Africa  ZAF           Life expectancy at birth, total (years)  SP.DYN.LE00.IN    48.406
# ...

# %%
df2=pd.read_csv("data\life_expectancy\API_SP.DYN.LE00.IN_DS2_en_csv_v2_1865151.csv",header=2,index_col=[0])

# %%
df2['1960']
# Out:
# Country Name
# Aruba           65.662
# Afghanistan     32.446
# Angola          37.524
# Albania         62.283
# Andorra            NaN
#                  ...
# Kosovo             NaN
# Yemen, Rep.     29.919
# South Africa    48.406
# Zambia          46.687
# Zimbabwe        53.019
# Name: 1960, Length: 264, dtype: float64

# %%
pd.plot(df2['1960'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-5dbb1f43e771> in <module>
# ----> 1 pd.plot(df2['1960'])
#
# c:\rajesh\jupyter\venv\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'plot'

# %%
s=pd.Series(df2['1960'].dropna())

# %%
s.plot()
# Out:
# <AxesSubplot:xlabel='Country Name'>

# %%
df.groupby(level=0).first().transpose()
# Out:
# Country Name  Afghanistan  Albania  Algeria  American Samoa  Andorra  Angola  \
# 1960               32.446   62.283   46.141             NaN      NaN  37.524
# 1961               32.962   63.301   46.599             NaN      NaN  37.811
# 1962               33.471   64.190   47.056             NaN      NaN  38.113
# 1963               33.971   64.914   47.509             NaN      NaN  38.430
# 1964               34.463   65.463   47.958             NaN      NaN  38.760
# ...                   ...      ...      ...             ...      ...     ...
# 2017               64.130   78.333   76.499             NaN      NaN  60.379
# 2018               64.486   78.458   76.693             NaN      NaN  60.782
# 2019                  NaN      NaN      NaN             NaN      NaN     NaN
# 2020                  NaN      NaN      NaN             NaN      NaN     NaN
# Unnamed: 65           NaN      NaN      NaN             NaN      NaN     NaN
#
# ...

# %%
life_expectancy=df.groupby(level=0).first().transpose()

# %%
life_expectancy.head()
# Out:
# Country Name  Afghanistan  Albania  Algeria  American Samoa  Andorra  Angola  \
# 1960               32.446   62.283   46.141             NaN      NaN  37.524
# 1961               32.962   63.301   46.599             NaN      NaN  37.811
# 1962               33.471   64.190   47.056             NaN      NaN  38.113
# 1963               33.971   64.914   47.509             NaN      NaN  38.430
# 1964               34.463   65.463   47.958             NaN      NaN  38.760
#
# Country Name  Antigua and Barbuda  Arab World  Argentina  Armenia  ...  \
# 1960                       61.968   46.546909     65.055   65.972  ...
# 1961                       62.523   47.141621     65.176   66.403  ...
# 1962                       63.049   47.731783     65.269   66.838  ...
# 1963                       63.540   48.320432     65.348   67.277  ...
# 1964                       63.992   48.910019     65.426   67.716  ...
#
# Country Name  Uzbekistan  Vanuatu  Venezuela, RB  Vietnam  \
# ...

# %%
list(life_expectancy.columns)
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Andorra',
#  'Angola',
#  'Antigua and Barbuda',
#  'Arab World',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas, The',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British Virgin Islands',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Caribbean small states',
#  'Cayman Islands',
#  'Central African Republic',
#  'Central Europe and the Baltics',
#  'Chad',
#  'Channel Islands',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Curacao',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Djibouti',
# ...

# %%
life_exectancy_subset = life_expectancy[['Australia','Canada','New Zealand','Switzerland','United Kingdom','United States']]

# %%
life_exectancy_subset.plot()
# Out:
# <AxesSubplot:>

# %%
life_exectancy_subset2 = life_expectancy[['India','Pakistan','Sri Lanka','Malaysia','Bangladesh','Bhutan']]

# %%
life_exectancy_subset2.plot()
# Out:
# <AxesSubplot:>
