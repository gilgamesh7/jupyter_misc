# %%
print("In God We Trust!")
# Out:
# In God We Trust!

# %%
import numpy as np
import pandas as pd

# %%
np.random.rand(100)
# Out:
# array([0.14735458, 0.77157481, 0.75582101, 0.80342261, 0.80057124,
#        0.6209821 , 0.43194613, 0.29013525, 0.77752557, 0.48369393,
#        0.77771137, 0.66330412, 0.78930951, 0.65834282, 0.50090413,
#        0.66583706, 0.47089952, 0.99590168, 0.14525547, 0.01589544,
#        0.31729445, 0.44157918, 0.65101735, 0.76557447, 0.8445322 ,
#        0.84717085, 0.14560154, 0.82956135, 0.33916187, 0.91284591,
#        0.50739353, 0.6130141 , 0.67305557, 0.07455296, 0.5310359 ,
#        0.28552645, 0.24319034, 0.81801739, 0.57952173, 0.44727587,
#        0.95424525, 0.9068588 , 0.14382945, 0.0169367 , 0.28800401,
#        0.48156525, 0.43710324, 0.39883608, 0.01264895, 0.54159035,
#        0.59783953, 0.53193035, 0.70507308, 0.37985851, 0.74343826,
#        0.91392836, 0.51260498, 0.03575699, 0.67016881, 0.35429877,
#        0.81873127, 0.64719911, 0.75334279, 0.7846997 , 0.14800796,
#        0.90089127, 0.53560214, 0.35365326, 0.85030692, 0.39068572,
# ...

# %%
s=pd.Series(np.random.rand(100))

# %%
s
# Out:
# 0     0.036325
# 1     0.627057
# 2     0.450310
# 3     0.259900
# 4     0.538083
#         ...
# 95    0.935124
# 96    0.392192
# 97    0.673784
# 98    0.509876
# 99    0.222667
# Length: 100, dtype: float64

# %%
s.values
# Out:
# array([0.03632493, 0.62705677, 0.45031035, 0.25989984, 0.53808257,
#        0.8217114 , 0.0414334 , 0.26479748, 0.3051253 , 0.11643033,
#        0.06956378, 0.13373898, 0.08086536, 0.51531296, 0.17632731,
#        0.56433465, 0.38338931, 0.66142657, 0.82131057, 0.35415494,
#        0.95434298, 0.42294451, 0.67341176, 0.36751199, 0.4212589 ,
#        0.80572732, 0.55918959, 0.81105473, 0.67709594, 0.06158131,
#        0.10837155, 0.65115379, 0.65289118, 0.06712925, 0.27965514,
#        0.64307022, 0.84327716, 0.31436309, 0.48345596, 0.67685545,
#        0.81884601, 0.21548513, 0.62127649, 0.69988299, 0.22164732,
#        0.68213206, 0.00325273, 0.03538986, 0.4763982 , 0.51679923,
#        0.19648567, 0.24370201, 0.80317799, 0.04265305, 0.97957374,
#        0.91271866, 0.60587311, 0.33812967, 0.68585169, 0.38679343,
#        0.53272395, 0.12061529, 0.20011202, 0.63294925, 0.94704161,
#        0.11138411, 0.97855996, 0.15527777, 0.7078435 , 0.39433739,
# ...

# %%
s.plot()
# Out:
# <AxesSubplot:>
